# %% [markdown]
# # 🔀 Python Conditionals Practice Exercises
#
# Conditionals are the decision-makers in programming! They let your code choose different paths based on conditions. These exercises will help you master if, elif, else statements and decision-making logic.
#
# ## 🚪 Basic If/Else Statements
#
# ### Exercise 1: Simple Decision Making

# %%
# TODO: Age verification system
age = 17  # Modify and run to see how the results change

# TODO: Create an if statement to check voting eligibility
if age >= 18:
    print("You are eligible to vote!")
else:
    print("You are not old enough to vote yet.")
    years_until_voting = 18 - age
    print(f"You can vote in {years_until_voting} year(s).")

# %%
# TODO: Temperature check
temperature = 75  # Fahrenheit - modify to see different results

if temperature > 80:
    print("It's hot outside!")
else:
    print("It's not too hot today.")

# %%
# TODO: Password strength checker
password = "mypass" # Modify your password
min_length = 8 # Modify the minimum length

# len() returns the number of characters in a string
if len(password) >= min_length:
    print("Password is long enough.")
else:
    chars_needed = min_length - len(password)
    print(f"Password too short! Need {chars_needed} more characters.")

# %%
# TODO: Grade pass/fail
score = 72
passing_grade = 70

# Write your if/else statement here
if # Your condition here:
    # Your code here
else:
    # Your code here

# %%
# TODO: Account balance check
balance = 150.50
withdrawal_amount = 75.00

# Check if withdrawal is possible
if # Your condition here:
    new_balance = # Your calculation here
    print(f"Withdrawal successful! New balance: ${new_balance:.2f}")
else:
    print("Insufficient funds for this withdrawal.")

# %% [markdown]
# ### Exercise 2: Number Comparison Practice

# %%
# TODO: Number guessing feedback
secret_number = 42
guess = 35

if guess == secret_number:
    print("🎉 Congratulations! You guessed the number!")
elif guess < secret_number:
    difference = secret_number - guess
    print(f"📈 Too low! You're {difference} away from the answer.")
else:
    difference = guess - secret_number
    print(f"📉 Too high! You're {difference} away from the answer.")

# %%
# TODO: Speed limit checker
speed_limit = 55
current_speed = 62

if current_speed <= speed_limit:
    print("✅ You're driving within the speed limit.")
else:
    over_limit = current_speed - speed_limit
    print(f"⚠️ You're going {over_limit} mph over the speed limit!")
    
    # Additional consequences based on how much over
    if over_limit <= 10:
        print("Minor speeding - warning issued.")
    else:
        print("Major speeding - ticket issued!")

# %%
# TODO: Practice with your own comparisons
num1 = 25
num2 = 30

# TODO: Compare the numbers and print appropriate messages
if # Your comparison here:
    # Print your message
elif # Another comparison:
    # Print your message
else:
    # Print your message

# %%
# TODO: Even or odd checker
number = 17

if # Your condition to check if even:
    print(f"{number} is even")
else:
    print(f"{number} is odd")

# %% [markdown]
# ## 🪜 Elif Chains
#
# ### Exercise 3: Grade Letter Assignment

# %%
# TODO: Convert numeric grade to letter grade
numeric_grade = 87 # Modify and run to see how the results change

if numeric_grade >= 97:
    letter_grade = "A+"
    message = "Outstanding work!"
elif numeric_grade >= 93:
    letter_grade = "A"
    message = "Excellent performance!"
elif numeric_grade >= 90:
    letter_grade = "A-"
    message = "Great job!"
elif numeric_grade >= 87:
    letter_grade = "B+"
    message = "Good work!"
elif numeric_grade >= 83:
    letter_grade = "B"
    message = "Solid performance."
elif numeric_grade >= 80:
    letter_grade = "B-"
    message = "Keep it up."
elif numeric_grade >= 77:
    letter_grade = "C+"
    message = "Room for improvement."
elif numeric_grade >= 73:
    letter_grade = "C"
    message = "Meeting expectations."
elif numeric_grade >= 70:
    letter_grade = "C-"
    message = "Just passing."
elif numeric_grade >= 67:
    letter_grade = "D+"
    message = "Below expectations."
elif numeric_grade >= 65:
    letter_grade = "D"
    message = "Needs significant improvement."
else:
    letter_grade = "F"
    message = "Failing grade."

print(f"Grade: {numeric_grade}% = {letter_grade}")
print(f"Feedback: {message}")

# %%
# TODO: Weather recommendation system
temperature = 45  # Fahrenheit

# TODO: Create elif chain for weather recommendations
if temperature >= 80:
    recommendation = "Perfect beach weather! 🏖️"
elif # Your condition for warm weather:
    recommendation = # Your message
elif # Your condition for cool weather:
    recommendation = # Your message
elif # Your condition for cold weather:
    recommendation = # Your message
else:
    recommendation = "Stay inside where it's warm! 🏠"

print(f"Temperature: {temperature}°F")
print(f"Recommendation: {recommendation}")

# %%
# TODO: BMI category classifier
height_feet = 5.8
weight_pounds = 160

# Convert to metric for BMI calculation
height_meters = height_feet * 0.3048
weight_kg = weight_pounds * 0.453592
bmi = weight_kg / (height_meters ** 2)

print(f"BMI: {bmi:.1f}")

# %%
# TODO: Complete the BMI classification
if bmi < 18.5: 
    category = "Underweight"
elif # Your condition for normal weight:
    category = # Your category
elif # Your condition for overweight:
    category = # Your category
else:
    category = "Obese"

print(f"BMI Category: {category}")

# %% [markdown]
# ### Exercise 4: Age Group Classification

# %%
# TODO: Comprehensive age group system
age = 25

# TODO: Create age group classifier with elif
if age < 0:
    group = "Invalid age"
    description = "Age cannot be negative"
elif age <= 2:
    group = "Infant"
    description = "Learning to walk and talk"
elif # Your condition for toddler:
    group = "Toddler"
    description = # Your description
elif # Your condition for child:
    group = "Child"
    description = # Your description
elif # Your condition for teenager:
    group = "Teenager"
    description = # Your description
elif # Your condition for young adult:
    group = "Young Adult"
    description = # Your description
elif # Your condition for adult:
    group = "Adult"
    description = # Your description
elif # Your condition for middle-aged:
    group = "Middle-aged"
    description = # Your description
elif # Your condition for senior:
    group = "Senior"
    description = # Your description
else:
    group = "Elder"
    description = "Wise and experienced"

print(f"Age: {age}")
print(f"Group: {group}")
print(f"Description: {description}")

# %%
# TODO: Movie rating system
viewer_age = 16
movie_rating = "PG-13"

print(f"\nViewer age: {viewer_age}, Movie rating: {movie_rating}")

if movie_rating == "G":
    print("✅ General audiences - all ages admitted")
elif movie_rating == "PG":
    print("✅ Parental guidance suggested")
elif movie_rating == "PG-13":
    if viewer_age >= 13:
        print("✅ You can watch this movie")
    else:
        print("❌ You need to be 13 or older")
elif movie_rating == "R":
    if # Your condition for R rating:
        print("✅ You can watch this movie")
    else:
        print("❌ You need to be 17 or older (or with parent)")
elif movie_rating == "NC-17":
    if # Your condition for NC-17:
        print("✅ You can watch this movie")
    else:
        print("❌ You must be 18 or older")
else:
    print("Unknown movie rating")

# %% [markdown]
# ## 🔗 Multiple Conditions
#
# ### Exercise 5: Login System

# %%
# TODO: Comprehensive login validation
username = "admin"
password = "secure123"
is_account_active = True
failed_attempts = 2
max_attempts = 3
requires_2fa = True
has_2fa_code = True
is_business_hours = False

# Check credentials
correct_username = username == "admin"
correct_password = password == "secure123"

print("🔐 Login Attempt Analysis:")
print(f"Username correct: {correct_username}")
print(f"Password correct: {correct_password}")
print(f"Account active: {is_account_active}")
print(f"Failed attempts: {failed_attempts}/{max_attempts}")
print(f"2FA required: {requires_2fa}, Has code: {has_2fa_code}")
print(f"Business hours: {is_business_hours}")

# TODO: Create complex login logic
if correct_username and correct_password:
    if is_account_active:
        if failed_attempts < max_attempts:
            if requires_2fa:
                if has_2fa_code:
                    if username == "admin" and is_business_hours:
                        print("✅ Admin login successful (business hours)")
                    elif username == "admin" and not is_business_hours:
                        print("⚠️ Admin login outside business hours - logged for security")
                    else:
                        print("✅ User login successful")
                else:
                    print("❌ 2FA code required")
            else:
                print("✅ Login successful (no 2FA required)")
        else:
            print("❌ Account locked due to too many failed attempts")
    else:
        print("❌ Account is deactivated")
else:
    print("❌ Invalid username or password")

# %%
# TODO: Scholarship eligibility checker
gpa = 3.7
family_income = 45000
extracurricular_hours = 60
is_first_generation = True
essay_submitted = True
letters_of_rec = 2

print(f"\n🎓 Scholarship Eligibility Check:")
print(f"GPA: {gpa}")
print(f"Family income: ${family_income:,}")
print(f"Extracurricular hours: {extracurricular_hours}")
print(f"First generation college: {is_first_generation}")
print(f"Essay submitted: {essay_submitted}")
print(f"Letters of recommendation: {letters_of_rec}")

# %%
# TODO: Create scholarship logic using and/or
basic_academic = gpa >= 3.5 and essay_submitted and letters_of_rec >= 2
financial_need = family_income <= 50000
community_involvement = extracurricular_hours >= 50
diversity_bonus = is_first_generation

if basic_academic and (financial_need or diversity_bonus) and community_involvement:
    if gpa >= 3.8 and financial_need:
        scholarship_amount = 10000
        print(f"🏆 Full scholarship awarded: ${scholarship_amount:,}")
    elif gpa >= 3.5 and (financial_need or diversity_bonus):
        scholarship_amount = 5000
        print(f"🥈 Partial scholarship awarded: ${scholarship_amount:,}")
    else:
        scholarship_amount = 2500
        print(f"🥉 Merit scholarship awarded: ${scholarship_amount:,}")
else:
    print("❌ Not eligible for scholarship")
    
    # Provide feedback on what's missing
    if not basic_academic:
        print("  - Need higher GPA or missing application materials")
    if not community_involvement:
        print(f"  - Need more community service ({50 - extracurricular_hours} more hours)")
    if not (financial_need or diversity_bonus):
        print("  - No financial need or diversity criteria met")

# %% [markdown]
# ### Exercise 6: Weather Activity Planner

# %%
# TODO: Weather-based activity recommendations
temperature = 72  # Fahrenheit
is_sunny = True
is_raining = False
wind_speed = 5  # mph
is_weekend = True
have_umbrella = False
have_jacket = True

print("🌤️ Weather Activity Planner")
print(f"Temperature: {temperature}°F")
print(f"Sunny: {is_sunny}, Raining: {is_raining}")
print(f"Wind: {wind_speed} mph, Weekend: {is_weekend}")
print(f"Have umbrella: {have_umbrella}, Have jacket: {have_jacket}")

print("\n📋 Activity Recommendations:")

# %%
# TODO: Beach/pool activity
good_beach_weather = temperature >= 75 and is_sunny and not is_raining and wind_speed < 15
if good_beach_weather and is_weekend:
    print("🏖️ Perfect day for the beach or pool!")
elif good_beach_weather:
    print("🏊 Great weather for outdoor swimming (if you have time)")

# %%
# TODO: Outdoor hiking
good_hiking_weather = # Your condition here (not too hot, not raining, not too windy)
if good_hiking_weather:
    if temperature < 60 and have_jacket:
        print("🥾 Great hiking weather - bring your jacket!")
    elif temperature >= 60:
        print("🥾 Perfect hiking weather!")
    else:
        print("🥾 Good for hiking but you might want a jacket")

# %%
# TODO: Outdoor sports
good_sports_weather = # Your condition (temperature range, not raining, low wind)
if good_sports_weather and is_weekend:
    print("⚽ Great day for outdoor sports!")

# %%
# TODO: Indoor activities
prefer_indoor = is_raining or temperature > 90 or temperature < 40 or wind_speed > 20
if prefer_indoor:
    if is_raining and have_umbrella:
        print("🌂 Could still go out with umbrella, but indoor activities might be better")
    else:
        print("🏠 Good day for indoor activities")

# %%
# TODO: Gardening
good_garden_weather = # Your condition (mild temp, not raining, not too windy)
if good_garden_weather:
    if is_sunny:
        print("🌱 Perfect for gardening!")
    else:
        print("🌱 Good for gardening (cloudy but dry)")

# %%
# TODO: Walking/jogging
if temperature >= 50 and temperature <= 80 and not is_raining:
    if wind_speed < 10:
        print("🚶 Great weather for a walk or jog!")
    else:
        print("🚶 Good for walking, but a bit windy")
elif is_raining and have_umbrella:
    print("🚶 Could walk with umbrella if you don't mind getting a bit wet")

# %%
# TODO: Photography
good_photo_weather = # Your condition (consider lighting, not raining)
if good_photo_weather:
    if is_sunny and wind_speed < 10:
        print("📸 Excellent conditions for outdoor photography!")
    elif not is_sunny and not is_raining:
        print("📸 Great for photography - nice diffused lighting!")

print("\n🎯 Summary: Plan your day based on these recommendations!")

# %% [markdown]
# ## 🏗️ Nested Conditionals
#
# ### Exercise 7: Bank Account System

# %%
# TODO: Advanced banking system with nested conditions
account_balance = 1250.75
account_type = "premium"  # basic, premium, vip
transaction_type = "withdrawal"  # deposit, withdrawal, transfer
amount = 800.00
daily_limit = 1000.00
todays_withdrawals = 150.00
is_international = False
has_overdraft = True
overdraft_limit = 500.00

print("🏦 Bank Transaction Processor")
print(f"Account balance: ${account_balance:,.2f}")
print(f"Account type: {account_type}")
print(f"Transaction: {transaction_type} ${amount:,.2f}")
print(f"Daily limit: ${daily_limit:,.2f}")
print(f"Today's withdrawals: ${todays_withdrawals:,.2f}")
print(f"International: {is_international}")
print(f"Overdraft protection: {has_overdraft}")

print("\n💳 Processing transaction...")

if transaction_type == "deposit":
    if amount > 0:
        if amount > 10000:
            print("⚠️ Large deposit - will be reported to authorities")
        new_balance = account_balance + amount
        print(f"✅ Deposit successful! New balance: ${new_balance:,.2f}")
    else:
        print("❌ Invalid deposit amount")
        
elif transaction_type == "withdrawal":
    # Check daily limit first
    if todays_withdrawals + amount <= daily_limit:
        # Check account balance
        if account_balance >= amount:
            # Regular withdrawal - sufficient funds
            if is_international:
                if account_type == "basic":
                    print("❌ International withdrawals not allowed for basic accounts")
                else:
                    fee = amount * 0.03  # 3% international fee
                    total_cost = amount + fee
                    if account_balance >= total_cost:
                        new_balance = account_balance - total_cost
                        print(f"✅ International withdrawal successful!")
                        print(f"   Amount: ${amount:,.2f}")
                        print(f"   Fee: ${fee:.2f}")
                        print(f"   New balance: ${new_balance:,.2f}")
                    else:
                        print(f"❌ Insufficient funds (need ${total_cost:,.2f} including fees)")
            else:
                # Domestic withdrawal
                new_balance = account_balance - amount
                print(f"✅ Withdrawal successful! New balance: ${new_balance:,.2f}")
        else:
            # Insufficient funds - check overdraft
            if has_overdraft:
                overdraft_needed = amount - account_balance
                if overdraft_needed <= overdraft_limit:
                    new_balance = account_balance - amount
                    overdraft_fee = 35.00  # Overdraft fee
                    final_balance = new_balance - overdraft_fee
                    print(f"⚠️ Overdraft withdrawal processed")
                    print(f"   Overdraft amount: ${overdraft_needed:.2f}")
                    print(f"   Overdraft fee: ${overdraft_fee:.2f}")
                    print(f"   New balance: ${final_balance:.2f}")
                else:
                    print(f"❌ Exceeds overdraft limit (${overdraft_limit:.2f})")
            else:
                print("❌ Insufficient funds and no overdraft protection")
    else:
        remaining_daily_limit = daily_limit - todays_withdrawals
        print(f"❌ Exceeds daily withdrawal limit")
        print(f"   Remaining limit: ${remaining_daily_limit:.2f}")
        
elif transaction_type == "transfer":
    # TODO: Add your transfer logic here
    if amount > 0:
        if account_balance >= amount:
            # Check transfer limits based on account type
            if account_type == "basic" and amount > 2000:
                print("❌ Transfer limit exceeded for basic account ($2,000)")
            elif account_type == "premium" and amount > 10000:
                print("❌ Transfer limit exceeded for premium account ($10,000)")
            else:
                # Process transfer
                transfer_fee = 0
                if account_type == "basic" and amount > 500:
                    transfer_fee = 5.00
                
                total_cost = amount + transfer_fee
                if account_balance >= total_cost:
                    new_balance = account_balance - total_cost
                    print(f"✅ Transfer successful!")
                    print(f"   Amount transferred: ${amount:,.2f}")
                    if transfer_fee > 0:
                        print(f"   Transfer fee: ${transfer_fee:.2f}")
                    print(f"   New balance: ${new_balance:,.2f}")
                else:
                    print(f"❌ Insufficient funds (need ${total_cost:.2f} including fees)")
        else:
            print("❌ Insufficient funds for transfer")
    else:
        print("❌ Invalid transfer amount")
else:
    print("❌ Unknown transaction type")

# %% [markdown]
# ### Exercise 8: Student Admission System

# %%
# TODO: Complex college admission decision system
gpa = 3.6
sat_score = 1350
act_score = 28
extracurriculars = 4  # Number of activities
volunteer_hours = 120
has_leadership = True
essay_quality = "excellent"  # poor, fair, good, excellent
letters_of_rec = 3
is_legacy = False
is_in_state = True
family_income = 65000
first_generation = True
special_talent = "music"  # None, sports, music, art, etc.

print("🎓 College Admission Evaluation System")
print(f"Academic: GPA {gpa}, SAT {sat_score}, ACT {act_score}")
print(f"Activities: {extracurriculars} extracurriculars, {volunteer_hours} volunteer hours")
print(f"Leadership: {has_leadership}, Essay: {essay_quality}")
print(f"Letters of recommendation: {letters_of_rec}")
print(f"Background: Legacy {is_legacy}, In-state {is_in_state}")
print(f"Income: ${family_income:,}, First gen: {first_generation}")
print(f"Special talent: {special_talent}")

print("\n📋 Evaluation Process...")

# Academic qualification check
if gpa >= 2.5:
    print("✅ Minimum GPA requirement met")
    
    # Test score evaluation
    if sat_score >= 1200 or act_score >= 25:
        print("✅ Standardized test requirement met")
        
        # Strong academic performance
        if gpa >= 3.8 and (sat_score >= 1450 or act_score >= 32):
            academic_tier = "excellent"
            print("🌟 Excellent academic performance")
        elif gpa >= 3.5 and (sat_score >= 1300 or act_score >= 28):
            academic_tier = "strong"
            print("💪 Strong academic performance")
        else:
            academic_tier = "good"
            print("👍 Good academic performance")
        
        # Extracurricular evaluation
        if extracurriculars >= 3 and volunteer_hours >= 50:
            if has_leadership and volunteer_hours >= 100:
                extracurricular_tier = "exceptional"
                print("🏆 Exceptional extracurricular involvement")
            elif has_leadership or volunteer_hours >= 80:
                extracurricular_tier = "strong"
                print("💼 Strong extracurricular involvement")
            else:
                extracurricular_tier = "good"
                print("👥 Good extracurricular involvement")
        else:
            extracurricular_tier = "weak"
            print("⚠️ Limited extracurricular involvement")
        
        # Application materials check
        if essay_quality in ["good", "excellent"] and letters_of_rec >= 2:
            if essay_quality == "excellent" and letters_of_rec >= 3:
                application_tier = "outstanding"
                print("📝 Outstanding application materials")
            else:
                application_tier = "solid"
                print("📄 Solid application materials")
        else:
            application_tier = "weak"
            print("📋 Application materials need improvement")
        
        # Special considerations
        bonus_points = 0
        
        if is_legacy:
            bonus_points += 1
            print("🏛️ Legacy status bonus")
        
        if first_generation:
            bonus_points += 1
            print("🎯 First-generation college student bonus")
        
        if family_income < 50000:
            bonus_points += 1
            print("💰 Low-income background consideration")
        
        if special_talent != "None":
            bonus_points += 1
            print(f"🎨 Special talent in {special_talent}")
        
        if is_in_state:
            print("🏠 In-state residency (tuition benefit)")
        
        # Final admission decision
        print("\n🎯 FINAL ADMISSION DECISION:")
        
        if academic_tier == "excellent":
            if extracurricular_tier in ["strong", "exceptional"] and application_tier in ["solid", "outstanding"]:
                decision = "ACCEPTED with HONORS"
                scholarship = "Merit scholarship recommended"
            else:
                decision = "ACCEPTED"
                scholarship = "Merit aid possible"
        elif academic_tier == "strong":
            if extracurricular_tier != "weak" and application_tier != "weak":
                if bonus_points >= 2:
                    decision = "ACCEPTED"
                    scholarship = "Need-based aid available"
                else:
                    decision = "ACCEPTED"
                    scholarship = "Standard aid package"
            else:
                if bonus_points >= 2:
                    decision = "WAITLISTED (strong chance)"
                    scholarship = "Aid depends on final admission"
                else:
                    decision = "WAITLISTED"
                    scholarship = "Limited aid if admitted from waitlist"
        else:  # academic_tier == "good"
            if extracurricular_tier == "exceptional" and application_tier == "outstanding":
                if bonus_points >= 2:
                    decision = "ACCEPTED"
                    scholarship = "Need-based aid available"
                else:
                    decision = "WAITLISTED"
                    scholarship = "Aid depends on final admission"
            else:
                if bonus_points >= 3:
                    decision = "WAITLISTED"
                    scholarship = "Aid depends on final admission"
                else:
                    decision = "REJECTED"
                    scholarship = "N/A"
        
        print(f"🎊 Decision: {decision}")
        print(f"💝 Financial Aid: {scholarship}")
        print(f"🏅 Bonus Points Earned: {bonus_points}")
        
    else:
        print("❌ Test scores below minimum requirements")
        print("💡 Consider retaking SAT/ACT or applying to different schools")
else:
    print("❌ GPA below minimum requirements")
    print("💡 Consider community college first to improve academic record")

# %% [markdown]
# ## ⚡ Ternary Operator (Shorthand If)
#
# ### Exercise 9: Quick Decision Making

# %%
# TODO: Practice with ternary operator (condition) ? true_value : false_value
# Python syntax: true_value if condition else false_value

age = 20
temperature = 75
score = 85
balance = -50.00
is_member = True

print("🔥 Ternary Operator Practice")

# Basic examples
voting_status = "Can vote" if age >= 18 else "Too young to vote"
print(f"Age {age}: {voting_status}")

weather_outfit = "Shorts and t-shirt" if temperature > 70 else "Pants and jacket"
print(f"Temperature {temperature}°F: {weather_outfit}")

grade_status = "Passing" if score >= 70 else "Failing"
print(f"Score {score}: {grade_status}")

account_status = "Positive" if balance >= 0 else "Overdrawn"
print(f"Balance ${balance}: {account_status}")

# %%
# TODO: Create your own ternary expressions
membership_price = # Your ternary here (discount for members)
print(f"Membership status: {'Member' if is_member else 'Non-member'}, Price: ${membership_price}")

# More complex examples
speed_limit = 55
current_speed = 62
ticket_amount = 50 + (current_speed - speed_limit) * 5 if current_speed > speed_limit else 0
print(f"Speed: {current_speed} mph, Ticket: ${ticket_amount}")

# Nested ternary (use sparingly!)
grade_letter = "A" if score >= 90 else ("B" if score >= 80 else ("C" if score >= 70 else "F"))
print(f"Score {score} = Grade {grade_letter}")

# %%
# TODO: Practice exercises - convert these if/else to ternary
print("\n📝 Practice Conversions:")

# Exercise 1: Convert this if/else to ternary
hours_worked = 45
# Traditional if/else:
if hours_worked > 40:
    overtime = "Yes"
else:
    overtime = "No"
print(f"Traditional: Hours {hours_worked}, Overtime: {overtime}")

# %%
# TODO: Convert to ternary
overtime_ternary = # Your ternary expression here
print(f"Ternary: Hours {hours_worked}, Overtime: {overtime_ternary}")

# Exercise 2: Convert this if/else to ternary
password_length = 12
# Traditional if/else:
if password_length >= 8:
    strength = "Strong"
else:
    strength = "Weak"
print(f"Traditional: Password length {password_length}, Strength: {strength}")

# %%
# TODO: Convert to ternary
strength_ternary = # Your ternary expression here
print(f"Ternary: Password length {password_length}, Strength: {strength_ternary}")

# Exercise 3: Multiple ternary operators
items_in_cart = 3
total_price = 75.50

# Calculate shipping based on multiple conditions
shipping_cost = 0 if total_price >= 100 else (5.99 if items_in_cart >= 3 else 9.99)
final_total = total_price + shipping_cost

print(f"\nShopping Cart Analysis:")
print(f"Items: {items_in_cart}, Subtotal: ${total_price:.2f}")
print(f"Shipping: ${shipping_cost:.2f}, Total: ${final_total:.2f}")

# %%
# TODO: Create a ternary for tax calculation
state = "CA"  # Different states have different tax rates
tax_rate = # Your ternary here (CA = 9.5%, TX = 6.25%, OR = 0%)
tax_amount = final_total * tax_rate
grand_total = final_total + tax_amount

print(f"State: {state}, Tax rate: {tax_rate:.1%}")
print(f"Tax: ${tax_amount:.2f}, Grand total: ${grand_total:.2f}")

# %% [markdown]
# ## 🎭 Truthiness and Boolean Testing
#
# ### Exercise 10: Working with Truthy and Falsy Values

# %%
# TODO: Understanding truthiness in conditionals
print("🎭 Truthiness in Conditional Statements")

# Test various values for truthiness
test_values = [
    0, 1, -1, 0.0, 3.14,
    "", "hello", " ",
    [], [1, 2, 3], [0],
    {}, {"key": "value"},
    None, True, False
]

for value in test_values:
    if value:
        result = "Truthy ✅"
    else:
        result = "Falsy ❌"
    print(f"{str(value):<15} {type(value).__name__:<10} -> {result}")

print("\n📋 Practical Applications:")

# %%
# TODO: User input validation using truthiness
user_name = ""  # Empty string
user_email = "user@example.com"
user_phone = None
user_preferences = {}
shopping_cart = []

print("User Profile Validation:")

# Check each field using truthiness
if user_name:
    print(f"✅ Name: {user_name}")
else:
    print("❌ Name: Missing or empty")

if user_email:
    print(f"✅ Email: {user_email}")
else:
    print("❌ Email: Missing or empty")

if user_phone:
    print(f"✅ Phone: {user_phone}")
else:
    print("❌ Phone: Missing or None")

if user_preferences:
    print(f"✅ Preferences: {len(user_preferences)} items")
else:
    print("❌ Preferences: No preferences set")

if shopping_cart:
    print(f"✅ Shopping cart: {len(shopping_cart)} items")
else:
    print("🛒 Shopping cart: Empty")

# %%
# TODO: Default value assignment using truthiness
print("\n🔧 Default Value Assignment:")

# Using or for default values
display_name = user_name or "Guest User"
contact_method = user_email or user_phone or "No contact info"
cart_status = "Items in cart" if shopping_cart else "Cart is empty"

print(f"Display name: {display_name}")
print(f"Contact method: {contact_method}")
print(f"Cart status: {cart_status}")

# %%
# TODO: Configuration system using truthiness
print("\n⚙️ Configuration System:")

config = {
    "debug_mode": True,
    "max_connections": 100,
    "api_key": "",
    "cache_size": 0,
    "allowed_domains": [],
    "admin_email": None
}

# Check configuration validity
for key, value in config.items():
    status = "✅ Set" if value else "❌ Missing/Empty"
    print(f"{key}: {value} -> {status}")

# System readiness check
required_configs = ["api_key", "admin_email", "allowed_domains"]
system_ready = all(config[key] for key in required_configs)

if system_ready:
    print("🚀 System ready to start!")
else:
    missing = [key for key in required_configs if not config[key]]
    print(f"⚠️ System not ready. Missing: {', '.join(missing)}")

# %%
# TODO: Smart conditional logic
print("\n🧠 Smart Conditional Logic:")

def check_file_access(filename, content, permissions):
    """Check if file operations are possible"""
    if not filename:
        return "Error: No filename provided"
    
    if not content:
        return "Warning: File appears to be empty"
    
    if not permissions:
        return "Error: No permissions set"
    
    return "File access OK"

# Test file access scenarios
test_files = [
    ("", "some content", ["read"]),
    ("document.txt", "", ["read", "write"]),
    ("config.json", '{"key": "value"}', []),
    ("data.csv", "name,age\nJohn,25", ["read", "write"])
]

for filename, content, permissions in test_files:
    result = check_file_access(filename, content, permissions)
    print(f"File: '{filename}' -> {result}")
# Out:
# 🧠 Smart Conditional Logic:
# File: '' -> Error: No filename provided
# File: 'document.txt' -> Warning: File appears to be empty
# File: 'config.json' -> Error: No permissions set
# File: 'data.csv' -> File access OK

# %% [markdown]
# ## 🏆 Challenge Problems
#
# ### Exercise 11: Advanced Decision Tree - Medical Diagnosis System

# %%
# CHALLENGE: Create a medical symptom assessment system
# This is for educational purposes only - not real medical advice!

print("🏥 SYMPTOM ASSESSMENT SYSTEM (Educational Only)")
print("This is a programming exercise - consult real doctors for medical advice!")
print("=" * 70)

# Patient information
age = 35
temperature = 101.5  # Fahrenheit
has_fever = temperature >= 100.4
has_headache = True
has_cough = False
has_sore_throat = True
has_body_aches = True
has_nausea = False
has_runny_nose = False
difficulty_breathing = False
chest_pain = False
days_with_symptoms = 2
recent_travel = False
contact_with_sick = True
chronic_conditions = ["diabetes"]  # List of conditions
medications = ["metformin"]

print(f"👤 Patient Profile:")
print(f"Age: {age}, Temperature: {temperature}°F")
print(f"Symptoms: Fever={has_fever}, Headache={has_headache}, Cough={has_cough}")
print(f"          Sore throat={has_sore_throat}, Body aches={has_body_aches}")
print(f"          Nausea={has_nausea}, Runny nose={has_runny_nose}")
print(f"Serious: Breathing issues={difficulty_breathing}, Chest pain={chest_pain}")
print(f"History: Days with symptoms={days_with_symptoms}, Travel={recent_travel}")
print(f"         Contact with sick={contact_with_sick}")
print(f"Medical: Conditions={chronic_conditions}, Medications={medications}")

print(f"\n🔍 ASSESSMENT PROCESS:")

# Emergency symptoms check first
emergency_symptoms = difficulty_breathing or chest_pain or temperature >= 103

if emergency_symptoms:
    urgency = "EMERGENCY"
    recommendation = "Seek immediate emergency care"
    print("🚨 EMERGENCY SYMPTOMS DETECTED")
    
else:
    # High-risk patient check
    high_risk = age >= 65 or chronic_conditions or (age >= 50 and medications)
    
    if high_risk:
        print("⚠️ High-risk patient identified")
        
        # High-risk assessment
        if has_fever and (has_cough or difficulty_breathing):
            if contact_with_sick or recent_travel:
                urgency = "HIGH"
                recommendation = "Contact doctor immediately - possible infection"
            else:
                urgency = "MODERATE-HIGH"
                recommendation = "Contact doctor today - respiratory symptoms with fever"
        elif has_fever and days_with_symptoms >= 3:
            urgency = "MODERATE"
            recommendation = "Contact doctor - prolonged fever in high-risk patient"
        else:
            urgency = "LOW-MODERATE"
            recommendation = "Monitor symptoms, contact doctor if worsening"
    
    else:
        # Standard patient assessment
        print("✅ Standard risk patient")
        
        # Count symptoms for severity
        symptom_count = sum([
            has_fever, has_headache, has_cough, has_sore_throat,
            has_body_aches, has_nausea, has_runny_nose
        ])
        
        if symptom_count >= 5:
            severity = "High"
        elif symptom_count >= 3:
            severity = "Moderate"
        else:
            severity = "Low"
        
        print(f"Symptom count: {symptom_count}/7, Severity: {severity}")
        
        # Flu-like symptoms pattern
        flu_pattern = has_fever and has_body_aches and (has_headache or has_cough)
        
        # Cold-like symptoms pattern
        cold_pattern = has_runny_nose or (has_sore_throat and not has_fever)
        
        # Stomach bug pattern
        stomach_pattern = has_nausea and not (has_cough or has_runny_nose)
        
        if flu_pattern:
            if contact_with_sick and days_with_symptoms <= 2:
                likely_condition = "Possible flu"
                if severity == "High":
                    urgency = "MODERATE"
                    recommendation = "Contact doctor - severe flu-like symptoms"
                else:
                    urgency = "LOW"
                    recommendation = "Rest, fluids, monitor symptoms. Contact doctor if worsening"
            else:
                likely_condition = "Viral illness"
                urgency = "LOW"
                recommendation = "Rest and fluids, contact doctor if no improvement in 3-5 days"
        
        elif cold_pattern:
            likely_condition = "Possible cold"
            if days_with_symptoms >= 7:
                urgency = "LOW-MODERATE"
                recommendation = "Contact doctor - prolonged cold symptoms"
            else:
                urgency = "LOW"
                recommendation = "Rest, fluids, over-the-counter remedies"
        
        elif stomach_pattern:
            likely_condition = "Possible stomach bug"
            if days_with_symptoms >= 3:
                urgency = "MODERATE"
                recommendation = "Contact doctor - prolonged GI symptoms"
            else:
                urgency = "LOW"
                recommendation = "Clear fluids, bland diet, rest"
        
        else:
            likely_condition = "Non-specific illness"
            if severity == "High" or days_with_symptoms >= 5:
                urgency = "MODERATE"
                recommendation = "Contact doctor for evaluation"
            else:
                urgency = "LOW"
                recommendation = "Monitor symptoms, contact doctor if worsening"

# Final assessment report
print(f"\n📋 ASSESSMENT RESULTS:")
print(f"🏥 Urgency Level: {urgency}")
if 'likely_condition' in locals():
    print(f"🔬 Likely Condition: {likely_condition}")
print(f"💡 Recommendation: {recommendation}")

# Additional care instructions
print(f"\n🏠 GENERAL CARE INSTRUCTIONS:")

if has_fever:
    print("🌡️ For fever: Rest, fluids, fever reducers as needed")

if has_cough:
    print("😷 For cough: Stay hydrated, consider throat lozenges")

if has_sore_throat:
    print("🍯 For sore throat: Warm salt water gargle, throat lozenges")

if has_body_aches:
    print("💊 For body aches: Rest, over-the-counter pain relievers")

if has_nausea:
    print("🥤 For nausea: Clear fluids, bland foods, rest")

print(f"\n⚠️ WHEN TO SEEK IMMEDIATE CARE:")
print(f"   • Difficulty breathing or chest pain")
print(f"   • Temperature above 103°F")
print(f"   • Severe dehydration")
print(f"   • Symptoms rapidly worsening")
print(f"   • Any concerning changes")

print(f"\n⚕️ DISCLAIMER: This is a programming exercise for educational purposes.")
print(f"   Always consult with qualified healthcare providers for medical advice.")

# %% [markdown]
# ### Exercise 12: Game Logic - Text Adventure

# %%
# CHALLENGE: Create a text-based adventure game with complex decision trees

print("🎮 TEXT ADVENTURE: The Mysterious Castle")
print("Navigate through the castle using conditional logic!")
print("=" * 50)

# Player stats
player_health = 100
player_strength = 15
player_intelligence = 12
player_luck = 8
player_gold = 50

# Inventory
has_sword = False
has_key = False
has_potion = True
has_torch = True
has_map = False

# Game state
current_room = "entrance"
dragon_defeated = False
treasure_found = False
princess_rescued = False

print(f"👤 Player Stats:")
print(f"Health: {player_health}, Strength: {player_strength}, Intelligence: {player_intelligence}, Luck: {player_luck}")
print(f"Gold: {player_gold}")
print(f"Inventory: Sword={has_sword}, Key={has_key}, Potion={has_potion}, Torch={has_torch}, Map={has_map}")

print(f"\n🏰 You stand before a mysterious castle...")

# Game logic using nested conditionals
if current_room == "entrance":
    print("\n🚪 ENTRANCE HALL")
    print("You see three doors: North (Armory), East (Library), West (Kitchen)")
    
    # Player choice simulation (in real game, this would be user input)
    player_choice = "north"  # Simulating player choosing north
    print(f"You choose to go {player_choice}")
    
    if player_choice == "north":
        current_room = "armory"
        print("\n⚔️ ARMORY")
        print("You find an ancient sword glowing with magic!")
        
        if player_strength >= 12:
            has_sword = True
            player_strength += 5  # Sword bonus
            print("✅ You're strong enough to wield the magic sword!")
            print(f"Your strength increases to {player_strength}")
        else:
            print("❌ You're not strong enough to lift the heavy sword")
            print("The sword remains on its pedestal")
    
    elif player_choice == "east":
        current_room = "library"
        print("\n📚 LIBRARY")
        print("Ancient books and scrolls fill the shelves")
        
        if player_intelligence >= 10:
            has_map = True
            player_intelligence += 3
            print("✅ You decipher an ancient map of the castle!")
            print(f"Your intelligence increases to {player_intelligence}")
            print("The map reveals secret passages and the dragon's weakness")
        else:
            print("❌ The ancient texts are too complex to understand")
            print("You leave the library empty-handed")
    
    elif player_choice == "west":
        current_room = "kitchen"
        print("\n🍳 KITCHEN")
        print("You smell something delicious cooking...")
        
        if has_torch:
            print("Your torch illuminates a hidden chest!")
            if player_luck >= 7:
                player_gold += 100
                has_key = True
                print(f"🍀 Lucky find! You discover 100 gold and a mysterious key!")
                print(f"Your gold: {player_gold}")
            else:
                player_gold += 25
                print(f"You find 25 gold pieces. Your gold: {player_gold}")
        else:
            print("Without light, you can't explore properly")
            player_health -= 10  # Stumble in darkness
            print(f"You stumble and hurt yourself. Health: {player_health}")

# Continue to dragon encounter
print(f"\n🐉 DRAGON'S LAIR")
print("You venture deeper and encounter a fearsome dragon!")
print("The dragon blocks the path to the treasure chamber")

# Dragon battle logic
if has_sword and player_strength >= 18:
    print("\n⚔️ EPIC BATTLE")
    if has_map:
        print("📜 Your map reveals the dragon's weakness!")
        print("💥 You strike the dragon's vulnerable spot with your magic sword!")
        dragon_defeated = True
        player_health -= 20  # Battle damage
        print(f"🏆 Dragon defeated! Health remaining: {player_health}")
    else:
        print("⚔️ You fight bravely with your sword, but it's a tough battle")
        if player_luck >= 6:
            dragon_defeated = True
            player_health -= 40
            print(f"🍀 Lucky victory! Dragon defeated! Health: {player_health}")
        else:
            player_health -= 60
            print(f"💔 You're badly wounded but manage to drive off the dragon")
            print(f"Health: {player_health}")
            if player_health <= 0:
                print("💀 You have been defeated! Game Over.")

elif player_intelligence >= 15 and has_map:
    print("\n🧠 CLEVER SOLUTION")
    print("Using your intelligence and the ancient map, you discover a riddle!")
    print("You solve the riddle and the dragon, impressed, lets you pass peacefully")
    dragon_defeated = True
    print("✨ No battle necessary - wisdom triumphs over strength!")

elif has_potion and player_luck >= 8:
    print("\n🧪 ALCHEMICAL SOLUTION")
    print("Your potion contains a sleeping draught!")
    print("🍀 With great luck, you manage to put the dragon to sleep")
    dragon_defeated = True
    has_potion = False
    print("😴 The dragon sleeps peacefully as you sneak past")

else:
    print("\n😰 RETREAT")
    print("Without proper equipment or skills, you must retreat!")
    print("The dragon is too powerful to face directly")
    player_health -= 10  # Retreat damage
    print(f"You escape with minor injuries. Health: {player_health}")

# Treasure chamber
if dragon_defeated:
    print(f"\n💎 TREASURE CHAMBER")
    print("With the dragon defeated, you enter the treasure chamber!")
    
    if has_key:
        print("🗝️ Your mysterious key opens a special chest!")
        treasure_value = 1000
        print(f"💰 You find the legendary treasure worth {treasure_value} gold!")
        player_gold += treasure_value
        treasure_found = True
        
        # Bonus: Princess rescue
        print("👸 You also find a princess who was held captive!")
        if player_health >= 50:
            princess_rescued = True
            print("✅ You're healthy enough to escort the princess to safety")
        else:
            print("😞 You're too wounded to safely escort the princess")
            print("You promise to return with help")
    
    else:
        treasure_value = 500
        print(f"💰 You find treasure worth {treasure_value} gold!")
        player_gold += treasure_value
        treasure_found = True

# Final scoring
print(f"\n🏁 ADVENTURE COMPLETE!")
print(f"=" * 30)

final_score = 0

if dragon_defeated:
    final_score += 100
    print(f"🐉 Dragon defeated: +100 points")

if treasure_found:
    final_score += 50
    print(f"💎 Treasure found: +50 points")

if princess_rescued:
    final_score += 75
    print(f"👸 Princess rescued: +75 points")

final_score += player_gold // 10  # Bonus for gold
final_score += player_health // 5  # Bonus for remaining health

print(f"💰 Final gold: {player_gold}")
print(f"❤️ Final health: {player_health}")
print(f"🏆 FINAL SCORE: {final_score} points")

# Determine ending
if final_score >= 200:
    ending = "LEGENDARY HERO"
    print(f"🌟 {ending}: You are now a legend throughout the land!")
elif final_score >= 150:
    ending = "GREAT ADVENTURER"
    print(f"⭐ {ending}: Your deeds will be remembered for generations!")
elif final_score >= 100:
    ending = "SUCCESSFUL QUEST"
    print(f"✨ {ending}: You completed your quest admirably!")
else:
    ending = "HUMBLE BEGINNING"
    print(f"🌱 {ending}: Every great hero starts somewhere!")

print(f"\n🎮 Thanks for playing! Your choices and conditional logic determined your fate!")

# %% [markdown]
# ## 🎉 Congratulations!
#
# You've completed the Python conditionals exercises! You've mastered:
#
# - **Basic If/Else** - Simple decision making with two paths
# - **Elif Chains** - Multiple condition checking with elegant flow
# - **Multiple Conditions** - Complex logic with `and`, `or`, `not` operators
# - **Nested Conditionals** - Sophisticated decision trees and hierarchical logic
# - **Ternary Operator** - Concise conditional expressions for simple cases
# - **Truthiness** - Understanding how different values behave in boolean contexts
# - **Real-World Applications** - Banking, medical, gaming, and business logic systems
#
# ### Key Takeaways:
# - Conditionals control the flow of your program based on data and logic
# - Use `elif` instead of multiple `if` statements for mutually exclusive conditions
# - Complex conditions can be built using logical operators (`and`, `or`, `not`)
# - Nested conditionals create sophisticated decision trees
# - Ternary operators are great for simple conditional assignments
# - Understanding truthiness helps with validation and default value patterns
# - Good conditional logic makes programs intelligent and responsive
#
# ### Next Steps:
# 1. Practice creating your own decision-making systems
# 2. Try building interactive programs with user choices
# 3. Move on to loops and iteration lessons
#
# Great job mastering conditional logic! 🐍🔀
