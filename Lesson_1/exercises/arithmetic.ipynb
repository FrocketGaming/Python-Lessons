# %% [markdown]
# # 🧮 Python Arithmetic Practice Exercises
#
# These exercises will help you master Python arithmetic operations and mathematical calculations. Work through each section to build your skills!
#
# ## 🔢 Basic Arithmetic Operations
#
# ### Exercise 1: Simple Calculator

# %%
# TODO: Create variables for two numbers
num1 = 15
num2 = 4

# TODO: Calculate and print all basic operations
addition = # Your code here
subtraction = # Your code here
multiplication = # Your code here
division = # Your code here
exponent = # Your code here
floor_division = # Your code here
modulo = # Your code here

print(f"{num1} + {num2} = {addition}")
print(f"{num1} - {num2} = {subtraction}")
print(f"{num1} * {num2} = {multiplication}")
print(f"{num1} / {num2} = {division}")
print(f"{num1} ** {num2} = {exponent}")
print(f"{num1} // {num2} = {floor_division}")
print(f"{num1} % {num2} = {modulo}")

# %% [markdown]
# ### Exercise 2: Understanding Division Types

# %%
# Practice different types of division
dividend = 17
divisor = 5

# TODO: Calculate regular division (returns float)
regular_division = # Your code here

# TODO: Calculate floor division (returns integer part)
floor_division = # Your code here

# TODO: Calculate modulo (returns remainder)
remainder = # Your code here

print(f"Dividing {dividend} by {divisor}:")
print(f"Regular division: {dividend} / {divisor} = {regular_division}")
print(f"Floor division: {dividend} // {divisor} = {floor_division}")
print(f"Remainder (modulo): {dividend} % {divisor} = {remainder}")

# TODO: Verify the relationship: dividend = (divisor × quotient) + remainder
verification = (divisor * floor_division) + remainder
print(f"\nVerification: ({divisor} × {floor_division}) + {remainder} = {verification}")
print(f"Does it equal the dividend? {verification == dividend}")

# %% [markdown]
# ### Exercise 3: Practical Modulo Applications

# %%
# TODO: Use modulo to determine if numbers are even or odd
numbers = [12, 15, 20, 33, 44, 57]

print("Even/Odd Check:")
for num in numbers:
    remainder = num % 2
    if remainder == 0:
        print(f"{num} is even")
    else:
        print(f"{num} is odd")

print("\n" + "="*30 + "\n")

# TODO: Clock arithmetic - what time will it be?
current_hour = 10  # 10 AM
hours_to_add = 15  # Add 15 hours

# Since there are 24 hours in a day, use modulo 24
final_hour = # Your code here

print(f"Current time: {current_hour}:00")
print(f"After adding {hours_to_add} hours: {final_hour}:00")

# TODO: Days of the week (0=Sunday, 1=Monday, ..., 6=Saturday)
days = ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]
today = 2  # Tuesday
days_ahead = 10

future_day_index = # Your code here (use modulo 7)
future_day = days[future_day_index]

print(f"\nToday is {days[today]}")
print(f"In {days_ahead} days, it will be {future_day}")

# %% [markdown]
# ## 📐 Order of Operations (PEMDAS)
#
# ### Exercise 4: Understanding Operator Precedence

# %%
# PEMDAS: Parentheses, Exponents, Multiplication/Division, Addition/Subtraction

# TODO: Calculate these expressions step by step
expression1 = 2 + 3 * 4
expression2 = (2 + 3) * 4
expression3 = 2 ** 3 + 1
expression4 = 2 ** (3 + 1)
expression5 = 10 - 6 / 2 + 1

print("Expression evaluations:")
print(f"2 + 3 * 4 = {expression1}")  # Multiplication first: 2 + 12 = 14
print(f"(2 + 3) * 4 = {expression2}")  # Parentheses first: 5 * 4 = 20
print(f"2 ** 3 + 1 = {expression3}")  # Exponent first: 8 + 1 = 9
print(f"2 ** (3 + 1) = {expression4}")  # Parentheses first: 2 ** 4 = 16
print(f"10 - 6 / 2 + 1 = {expression5}")  # Division first: 10 - 3 + 1 = 8

# TODO: Predict the result before running:
# What will this expression equal?
complex_expression = 2 + 3 * 4 ** 2 - 1

# Step by step:
# 4 ** 2 = 16 (exponents first)
# 3 * 16 = 48 (multiplication)
# 2 + 48 - 1 = 49 (left to right for addition/subtraction)

print(f"\n2 + 3 * 4 ** 2 - 1 = {complex_expression}")
print("Did you predict 49?")

# %% [markdown]
# ### Exercise 5: Parentheses Practice

# %%
# TODO: Add parentheses to change the results
# Original: 20 - 10 + 3 * 2 = ?
original = 20 - 10 + 3 * 2
print(f"Original: 20 - 10 + 3 * 2 = {original}")

# TODO: Add parentheses to make the result equal 26
# Hint: Change the order of operations
modified1 = # Your code here with parentheses

# TODO: Add parentheses to make the result equal 60  
modified2 = # Your code here with parentheses

print(f"With parentheses for 26: {modified1}")
print(f"With parentheses for 60: {modified2}")

# TODO: Practice with your own expression
# Create an expression that equals 100 using: 5, 4, 3, 2, 1
# You can use +, -, *, /, ** and parentheses
your_expression = # Your creative solution here
print(f"\nYour expression that equals 100: {your_expression}")

# %% [markdown]
# ## 🔧 Built-in Math Functions
#
# ### Exercise 6: Working with Built-in Functions

# %%
# TODO: Practice with built-in math functions
test_scores = [85, 92, 78, 96, 88, 72, 95]
temperatures = [-5, 10, -12, 8, -3, 15, 0]
expenses = [120.50, 45.75, 89.25, 156.80, 67.40]

# TODO: Find the highest and lowest test scores
highest_score = # Your code here
lowest_score = # Your code here

print(f"Test Scores: {test_scores}")
print(f"Highest score: {highest_score}")
print(f"Lowest score: {lowest_score}")

# TODO: Find the warmest and coldest temperatures
warmest = # Your code here
coldest = # Your code here

print(f"\nTemperatures: {temperatures}")
print(f"Warmest: {warmest}°C")
print(f"Coldest: {coldest}°C")

# TODO: Calculate total expenses and convert negative temperatures to positive
total_expenses = # Your code here
absolute_temps = [abs(temp) for temp in temperatures]  # List comprehension using abs()

print(f"\nTotal expenses: ${total_expenses}")
print(f"Absolute temperatures: {absolute_temps}")

# TODO: Use divmod to split total expenses into dollars and cents
dollars, cents_decimal = divmod(total_expenses, 1)
cents = int(cents_decimal * 100)  # Convert decimal to cents

print(f"Total expenses: ${int(dollars)} and {cents} cents")

# %% [markdown]
# ## 📚 Math Module Practice
#
# ### Exercise 7: Geometry Calculations

# %%
import math

# TODO: Calculate circle properties
radius = 7.5

# Calculate area: π × r²
area = # Your code here (use math.pi)

# Calculate circumference: 2 × π × r  
circumference = # Your code here

print(f"Circle with radius {radius}:")
print(f"Area: {area:.2f}")
print(f"Circumference: {circumference:.2f}")

# TODO: Calculate square root and powers
number = 144
square_root = # Your code here (use math.sqrt)
cube_root = # Your code here (use math.pow for 1/3 power)

print(f"\nSquare root of {number}: {square_root}")
print(f"Cube root of {number}: {cube_root:.2f}")

# TODO: Ceiling and floor functions
decimal_number = 15.7
ceiling_value = # Your code here (math.ceil)
floor_value = # Your code here (math.floor)

print(f"\nNumber: {decimal_number}")
print(f"Ceiling (round up): {ceiling_value}")
print(f"Floor (round down): {floor_value}")

# %% [markdown]
# ## 🌍 Real-World Applications
#
# ### Exercise 8: Financial Calculator

# %%
# TODO: Compound Interest Calculator
# Formula: A = P(1 + r/n)^(nt)
# A = final amount, P = principal, r = annual rate, n = compounds per year, t = time in years

principal = 1000  # $1000 initial investment
annual_rate = 0.05  # 5% annual interest rate
compounds_per_year = 12  # Monthly compounding
years = 5  # 5 years

# TODO: Calculate compound interest
final_amount = # Your code here
interest_earned = final_amount - principal

print(f"Compound Interest Calculator:")
print(f"Principal: ${principal}")
print(f"Annual Rate: {annual_rate*100}%")
print(f"Compounding: {compounds_per_year} times per year")
print(f"Time: {years} years")
print(f"Final Amount: ${final_amount:.2f}")
print(f"Interest Earned: ${interest_earned:.2f}")

# TODO: Loan Payment Calculator
# Monthly payment formula: M = P * [r(1+r)^n] / [(1+r)^n - 1]
loan_amount = 20000  # $20,000 loan
monthly_rate = 0.04 / 12  # 4% annual rate, divided by 12 months
num_payments = 5 * 12  # 5 years * 12 months

# Calculate monthly payment
numerator = loan_amount * monthly_rate * (1 + monthly_rate) ** num_payments
denominator = (1 + monthly_rate) ** num_payments - 1
monthly_payment = numerator / denominator

total_paid = monthly_payment * num_payments
total_interest = total_paid - loan_amount

print(f"\nLoan Payment Calculator:")
print(f"Loan Amount: ${loan_amount}")
print(f"Monthly Payment: ${monthly_payment:.2f}")
print(f"Total Paid: ${total_paid:.2f}")
print(f"Total Interest: ${total_interest:.2f}")

# %% [markdown]
# ### Exercise 9: Unit Conversions

# %%
# TODO: Temperature conversions
celsius_temp = 25

# Convert Celsius to Fahrenheit: F = (C × 9/5) + 32
fahrenheit = # Your code here

# Convert Celsius to Kelvin: K = C + 273.15
kelvin = # Your code here

print(f"Temperature Conversions:")
print(f"{celsius_temp}°C = {fahrenheit}°F")
print(f"{celsius_temp}°C = {kelvin} K")

# TODO: Distance conversions
miles = 100
kilometers = miles * 1.60934
feet = miles * 5280
meters = kilometers * 1000

print(f"\nDistance Conversions:")
print(f"{miles} miles = {kilometers:.2f} km")
print(f"{miles} miles = {feet:,} feet")
print(f"{miles} miles = {meters:,.0f} meters")

# TODO: Weight conversions
pounds = 150
kilograms = # Your code here (1 pound = 0.453592 kg)
ounces = # Your code here (1 pound = 16 ounces)

print(f"\nWeight Conversions:")
print(f"{pounds} lbs = {kilograms:.2f} kg")
print(f"{pounds} lbs = {ounces} oz")

# TODO: Time conversions
hours = 2.5
minutes = # Your code here
seconds = # Your code here

print(f"\nTime Conversions:")
print(f"{hours} hours = {minutes} minutes")
print(f"{hours} hours = {seconds} seconds")

# %% [markdown]
# ## 🏆 Challenge Problems
#
# ### Exercise 10: Multi-Step Word Problems

# %%
# CHALLENGE 1: Pizza Party Calculator
# You're organizing a pizza party for 23 people
# Each pizza has 8 slices and costs $12.50
# Each person will eat 3 slices on average
# There's a 8% tax and you want to tip 18%

people = 23
slices_per_person = 3
slices_per_pizza = 8
cost_per_pizza = 12.50
tax_rate = 0.08
tip_rate = 0.18

# TODO: Calculate total slices needed
total_slices_needed = # Your code here

# TODO: Calculate number of pizzas needed (round up!)
import math
pizzas_needed = # Your code here (use math.ceil)

# TODO: Calculate costs
subtotal = # Your code here
tax_amount = # Your code here
tip_amount = # Your code here (tip on subtotal + tax)
total_cost = # Your code here
cost_per_person = # Your code here

print("🍕 Pizza Party Calculator 🍕")
print(f"People: {people}")
print(f"Total slices needed: {total_slices_needed}")
print(f"Pizzas needed: {pizzas_needed}")
print(f"Subtotal: ${subtotal:.2f}")
print(f"Tax: ${tax_amount:.2f}")
print(f"Tip: ${tip_amount:.2f}")
print(f"Total cost: ${total_cost:.2f}")
print(f"Cost per person: ${cost_per_person:.2f}")

# %%
# CHALLENGE 2: Study Schedule Planner
# You have 45 days until your exam
# You need to study 120 hours total
# You can't study on weekends (Saturdays and Sundays)
# You can study a maximum of 3 hours per day

total_days = 45
total_hours_needed = 120
max_hours_per_day = 3

# TODO: Calculate weekdays available (5 out of every 7 days)
weeks = total_days // 7
remaining_days = total_days % 7
weekend_days = weeks * 2  # 2 weekend days per week

# Count weekend days in remaining days (assuming we start on Monday)
# Days 0-6 represent Mon-Sun, so days 5,6 are weekends
additional_weekend_days = max(0, remaining_days - 5) if remaining_days > 5 else 0

total_weekend_days = weekend_days + additional_weekend_days
available_study_days = total_days - total_weekend_days

print("📚 Study Schedule Planner 📚")
print(f"Total days until exam: {total_days}")
print(f"Weekend days (no study): {total_weekend_days}")
print(f"Available study days: {available_study_days}")

# TODO: Calculate hours needed per day
hours_per_day = # Your code here

print(f"Hours needed per study day: {hours_per_day:.2f}")

# TODO: Check if it's feasible
if hours_per_day <= max_hours_per_day:
    print(f"✅ Feasible! You can study {hours_per_day:.1f} hours per day.")
else:
    print(f"❌ Not feasible! You need {hours_per_day:.1f} hours per day, but max is {max_hours_per_day}.")
    # TODO: Calculate how many extra days you need
    extra_days_needed = # Your code here
    print(f"You need {extra_days_needed} more study days.")

# %% [markdown]
# ## 🎉 Congratulations!
#
# You've completed the Python arithmetic exercises! You've practiced:
#
# - **Basic Operations** - Addition, subtraction, multiplication, division, exponents, floor division, modulo
# - **Order of Operations** - PEMDAS and using parentheses effectively
# - **Built-in Functions** - min, max, abs, sum, divmod
# - **Math Module** - pi, sqrt, ceil, floor, and more
# - **Real-World Applications** - Financial calculations, unit conversions, problem-solving
#
# ### Key Takeaways:
# - Python follows mathematical order of operations (PEMDAS)
# - Use parentheses to control the order of calculations
# - Floor division (//) gives you the whole number part
# - Modulo (%) gives you the remainder
# - The math module provides advanced mathematical functions
# - Practice with real-world problems helps solidify understanding
#
# ### Next Steps:
# 1. Review any exercises you found challenging
# 2. Try creating your own arithmetic problems
# 3. Move on to variables and operators lessons
#
# Great job! 🐍💪
